# %%
npm = 2006596996  # TODO: Isi NPM Anda

# %% [markdown]
# ## 1. Prepare Datasets

# %%
# Unduh dataset training dan testing
# !wget https://raw.githubusercontent.com/luthfibalaka/NLP-Lab-5/refs/heads/main/train.csv
# !wget https://raw.githubusercontent.com/luthfibalaka/NLP-Lab-5/refs/heads/main/test.csv

# %%
# Import packages yang relevan
import pandas as pd

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D
from sklearn.model_selection import train_test_split

# %%
# Load dataset training dan testing
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# Input Title
texts = train_df['description'].values 
labels = train_df['news_type'].values

# %%
# Jumlah kelas pada klasifikasi berdasarkan atribut news_type
num_classes = train_df['news_type'].nunique()

# %%
# Melatih dan melakukan tokenisasi pada teks
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

# %%
# Melakukan padding teks sepanjang maksimal maxlen
maxlen = 1000
X_train = pad_sequences(sequences, maxlen=maxlen)

# %%
# Memecah data training untuk mendapatkan data validation
X_train, X_val, y_train, y_val = train_test_split(X_train, labels, test_size=0.2, random_state=npm)

# %% [markdown]
# ## 2. Train and Test Embedding Model

# %%
# Mendefinisikan model dan beberapa komponen terkait
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=8))
model.add(GlobalAveragePooling1D())
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Melatih model
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/5
# 3000/3000 [==============================] - 24s 8ms/step - loss: 1.3532 - accuracy: 0.4796 - val_loss: 1.2707 - val_accuracy: 0.7824
# Epoch 2/5
# 3000/3000 [==============================] - 22s 7ms/step - loss: 1.1054 - accuracy: 0.7966 - val_loss: 0.9404 - val_accuracy: 0.7945
# Epoch 3/5
# 3000/3000 [==============================] - 24s 8ms/step - loss: 0.8026 - accuracy: 0.8287 - val_loss: 0.6927 - val_accuracy: 0.8339
# Epoch 4/5
# 3000/3000 [==============================] - 22s 7ms/step - loss: 0.6142 - accuracy: 0.8450 - val_loss: 0.5580 - val_accuracy: 0.8468
# Epoch 5/5
# 3000/3000 [==============================] - 22s 7ms/step - loss: 0.5083 - accuracy: 0.8591 - val_loss: 0.4810 - val_accuracy: 0.8606

# %%
# Menguji model pada data testing
test_sequences = tokenizer.texts_to_sequences(test_df['description'].values)
X_test = pad_sequences(test_sequences, maxlen=maxlen)
y_test = test_df['news_type'].values

loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy}')
# Out:
# 238/238 [==============================] - 1s 2ms/step - loss: 0.4897 - accuracy: 0.8554
# Test Accuracy: 0.855394721031189
